# %%
import pandas as pd

# %%
df = pd.read_csv("GooglePlay.csv")
df.tail(100)
# Out:
#        Unnamed: 0                                            App  \
# 10741       10741                       Fingerprint Quick Action
# 10742       10742                          GKPB FP Online Church
# 10743       10743                                 FP BW LCD View
# 10744       10744                                     FP Markets
# 10745       10745                                        FP Boss
# ...           ...                                            ...
# 10836       10836                               Sya9a Maroc - FR
# 10837       10837               Fr. Mike Schmitz Audio Teachings
# 10838       10838                         Parkinson Exercices FR
# 10839       10839                  The SCP Foundation DB fr nn5n
# 10840       10840  iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category  Rating Reviews                Size     Installs  \
# 10741                TOOLS     4.2    8484                1.7M   1,000,000+
# 10742            LIFESTYLE     5.0      32                7.9M       1,000+
# 10743               FAMILY     3.4      16                1.2M         500+
# 10744              FINANCE     NaN       1                2.0M         100+
# 10745              FINANCE     NaN       1                5.8M           1+
# ...                    ...     ...     ...                 ...          ...
# 10836               FAMILY     4.5      38                 53M       5,000+
# 10837               FAMILY     5.0       4                3.6M         100+
# 10838              MEDICAL     NaN       3                9.5M       1,000+
# 10839  BOOKS_AND_REFERENCE     4.5     114  Varies with device       1,000+
# 10840            LIFESTYLE     4.5  398307                 19M  10,000,000+
#
#        Type Price Content Rating             Genres Last Updated  \
# 10741  Free     0       Everyone              Tools    22-Jul-18
# 10742  Free     0       Everyone          Lifestyle    31-Dec-17
# 10743  Free     0       Everyone      Entertainment    31-Mar-16
# 10744  Free     0       Everyone            Finance    30-Jan-18
# 10745  Free     0       Everyone            Finance    27-Jul-18
# ...     ...   ...            ...                ...          ...
# 10836  Free     0       Everyone          Education    25-Jul-17
# 10837  Free     0       Everyone          Education     6-Jul-18
# 10838  Free     0       Everyone            Medical    20-Jan-17
# 10839  Free     0     Mature 17+  Books & Reference    19-Jan-15
# 10840  Free     0       Everyone          Lifestyle    25-Jul-18
#
#               Current Ver         Android Ver Unnamed: 14
# 10741              0.15.2          6.0 and up         NaN
# 10742               0.7.1          4.4 and up         NaN
# 10743                   1        4.0.3 and up         NaN
# 10744             1.0.0.0          4.3 and up         NaN
# 10745               1.0.2          5.0 and up         NaN
# ...                   ...                 ...         ...
# 10836                1.48          4.1 and up         NaN
# 10837                   1          4.1 and up         NaN
# 10838                   1          2.2 and up         NaN
# 10839  Varies with device  Varies with device         NaN
# 10840  Varies with device  Varies with device         NaN
#
# [100 rows x 15 columns]

# %%
output_cols = ['attribute name', "record count", 'null count', 'completeness']
output = []
for col in df.columns:
    record = []
    record.append(col)
    record.append(df[col].shape[0])
    record.append(df[df[col].isnull()].shape[0])
    completeness = 100.0 * float(df[col].shape[0] - df[df[col].isnull()].shape[0]) / float(df[col].shape[0])
    completeness = "{:.2f}".format(completeness)
    record.append(completeness)
    output.append(record)
    # pass

output_df = pd.DataFrame(output, columns=output_cols)
output_df
# Out:
#     attribute name  record count  null count completeness
# 0       Unnamed: 0         10841           0       100.00
# 1              App         10841           0       100.00
# 2         Category         10841           0       100.00
# 3           Rating         10841        1474        86.40
# 4          Reviews         10841           0       100.00
# 5             Size         10841           0       100.00
# 6         Installs         10841           0       100.00
# 7             Type         10841           1        99.99
# 8            Price         10841           0       100.00
# 9   Content Rating         10841           1        99.99
# 10          Genres         10841           0       100.00
# 11    Last Updated         10841           0       100.00
# 12     Current Ver         10841           8        99.93
# 13     Android Ver         10841           3        99.97
# 14     Unnamed: 14         10841       10342         4.60

# %% [raw]
# s = r'\b(0?[1-9]|[12][0-9]|3[01])-(Jan|Feb|Mar|apr|may|jun|jul|aug|sep|oct|nov|dec)-(\d+)\b'
# df['Last Updated'].str.match(s)
# df
